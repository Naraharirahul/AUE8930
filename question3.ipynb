# %%
# %matplotlib inline
from nuscenes.nuscenes import NuScenes

nusc = NuScenes(version='v1.0-mini', dataroot='D:\Documents\dataset', verbose=True)
# Out:
# ======
# Loading NuScenes tables for version v1.0-mini...
# 23 category,
# 8 attribute,
# 4 visibility,
# 911 instance,
# 12 sensor,
# 120 calibrated_sensor,
# 31206 ego_pose,
# 8 log,
# 10 scene,
# 404 sample,
# 31206 sample_data,
# 18538 sample_annotation,
# 4 map,
# Done loading in 0.586 seconds.
# ======
# Reverse indexing ...
# Done reverse indexing in 0.1 seconds.
# ======

# %%
nusc.list_scenes()
# Out:
# scene-0061, Parked truck, construction, intersectio... [18-07-24 03:28:47]   19s, singapore-onenorth, #anns:4622
# scene-0103, Many peds right, wait for turning car, ... [18-08-01 19:26:43]   19s, boston-seaport, #anns:2046
# scene-0655, Parking lot, parked cars, jaywalker, be... [18-08-27 15:51:32]   20s, boston-seaport, #anns:2332
# scene-0553, Wait at intersection, bicycle, large tr... [18-08-28 20:48:16]   20s, boston-seaport, #anns:1950
# scene-0757, Arrive at busy intersection, bus, wait ... [18-08-30 19:25:08]   20s, boston-seaport, #anns:592
# scene-0796, Scooter, peds on sidewalk, bus, cars, t... [18-10-02 02:52:24]   20s, singapore-queensto, #anns:708
# scene-0916, Parking lot, bicycle rack, parked bicyc... [18-10-08 07:37:13]   20s, singapore-queensto, #anns:2387
# scene-1077, Night, big street, bus stop, high speed... [18-11-21 11:39:27]   20s, singapore-hollandv, #anns:890
# scene-1094, Night, after rain, many peds, PMD, ped ... [18-11-21 11:47:27]   19s, singapore-hollandv, #anns:1762
# scene-1100, Night, peds in sidewalk, peds cross cro... [18-11-21 11:49:47]   19s, singapore-hollandv, #anns:935

# %%
my_scene = nusc.scene[0]

# %%
first_sample_token = my_scene['first_sample_token']
first_sample_token
# Out:
# 'ca9a282c9e77460f8360f564131a8af5'

# %%
my_sample = nusc.get('sample', first_sample_token)

# %%
# Camera viz
my_sample = nusc.sample[3]
nusc.render_sample_data(my_sample['data']['CAM_FRONT'])

# %%
# Lidar viz
nusc.render_sample_data(my_sample['data']['LIDAR_TOP'])

# %%
# radar viz
nusc.render_sample_data(my_sample['data']['RADAR_FRONT'])

# %%
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-15d973d166bd> in <module>
# ----> 1 nusc.render_pointcloud_in_image(my_sample['token'],
#       2                                 pointsensor_channel='LIDAR_TOP',
#       3                                 camera_channel='CAM_BACK',
#       4                                 render_intensity=False,
#       5                                 show_lidarseg=True,
#
# ~\anaconda3\envs\aue8930\lib\site-packages\nuscenes\nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, show_lidarseg_legend, verbose, lidarseg_preds_bin_path)
#     502                                    verbose: bool = True,
#     503                                    lidarseg_preds_bin_path: str = None) -> None:
# --> 504         self.explorer.render_pointcloud_in_image(sample_token, dot_size, pointsensor_channel=pointsensor_channel,
#     505                                                  camera_channel=camera_channel, out_path=out_path,
#     506                                                  render_intensity=render_intensity,
#
# ~\anaconda3\envs\aue8930\lib\site-packages\nuscenes\nuscenes.py in render_pointcloud_in_image(self, sample_token, dot_size, pointsensor_channel, camera_channel, out_path, render_intensity, show_lidarseg, filter_lidarseg_labels, ax, show_lidarseg_legend, verbose, lidarseg_preds_bin_path)
#     897         camera_token = sample_record['data'][camera_channel]
#     898
# --> 899         points, coloring, im = self.map_pointcloud_to_image(pointsensor_token, camera_token,
#     900                                                             render_intensity=render_intensity,
#     901                                                             show_lidarseg=show_lidarseg,
#
# ~\anaconda3\envs\aue8930\lib\site-packages\nuscenes\nuscenes.py in map_pointcloud_to_image(self, pointsensor_token, camera_token, min_dist, render_intensity, show_lidarseg, filter_lidarseg_labels, lidarseg_preds_bin_path)
#     766         if pointsensor['sensor_modality'] == 'lidar':
#     767             if show_lidarseg:
# --> 768                 assert hasattr(self.nusc, 'lidarseg'), 'Error: nuScenes-lidarseg not installed!'
#     769
#     770                 # Ensure that lidar pointcloud is from a keyframe.
#
# AssertionError: Error: nuScenes-lidarseg not installed!
